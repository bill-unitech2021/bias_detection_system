# %%
import pandas as pd

# %%
#read the data into the dataframe and print the first 10 rows
url = 'https://raw.githubusercontent.com/MaastrichtU-IDS/global-studies/main/semester4/tutorial4/inputs/tolerance_survey_data.csv'
df = pd.read_csv(url)
df.head(10)
# Out:
#    id   age  height country  language  freq_travel              q1  \
# 0   1  34.0     186   Spain       1.0          5.0           Agree
# 1   2  34.0     157      BR       2.0          3.0  Strongly Agree
# 2   3  27.0     191      RU       4.0          2.0           Agree
# 3   4  35.0     165      RU       3.0          5.0           Agree
# 4   5  34.0     164      ID       5.0          5.0  Strongly Agree
# 5   6   NaN     165      ID       3.0          3.0  Strongly Agree
# 6   8  32.0     222      ID       3.0          5.0           Agree
# 7   9  39.0     173      CN       4.0          5.0           Agree
# 8  10  29.0     177      AL       2.0          1.0             NaN
# 9  11  19.0     159      NI       2.0          4.0           Agree
#
#                q2                 q3              q4                 q5  \
# 0           Agree              Agree           Agree            Neutral
# 1           Agree            Neutral           Agree     Strongly Agree
# 2           Agree     Strongly Agree           Agree     Strongly Agree
# 3           Agree              Agree           Agree     Strongly Agree
# 4           Agree     Strongly Agree         Neutral            Neutral
# 5  Strongly Agree     Strongly Agree  Strongly Agree     Strongly Agree
# 6  Strongly Agree     Strongly Agree  Strongly Agree     Strongly Agree
# 7        Disagree  Strongly Disagree         Neutral  Strongly Disagree
# 8           Agree            Neutral         Neutral     Strongly Agree
# 9  Strongly Agree     Strongly Agree  Strongly Agree     Strongly Agree
#
#                q6              q7              q8
# 0        Disagree         Neutral         Neutral
# 1  Strongly Agree           Agree           Agree
# 2           Agree  Strongly Agree           Agree
# 3           Agree           Agree         Neutral
# 4           Agree           Agree  Strongly Agree
# 5  Strongly Agree  Strongly Agree  Strongly Agree
# 6  Strongly Agree           Agree           Agree
# 7         Neutral        Disagree           Agree
# 8  Strongly Agree  Strongly Agree         Neutral
# 9  Strongly Agree  Strongly Agree  Strongly Agree

# %%
print("The shape of the dataframe is",df.shape)
# Out:
# The shape of the dataframe is (150, 14)

# %%
print(df.iloc[1][1:3])
# Out:
# age       34.0
# height     157
# Name: 1, dtype: object

# %%
df.dtypes
# Out:
# id               int64
# age            float64
# height           int64
# country         object
# language       float64
# freq_travel    float64
# q1              object
# q2              object
# q3              object
# q4              object
# q5              object
# q6              object
# q7              object
# q8              object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           150 non-null    int64
#  1   age          137 non-null    float64
#  2   height       150 non-null    int64
#  3   country      150 non-null    object
#  4   language     143 non-null    float64
#  5   freq_travel  143 non-null    float64
#  6   q1           149 non-null    object
#  7   q2           150 non-null    object
#  8   q3           149 non-null    object
#  9   q4           149 non-null    object
#  10  q5           150 non-null    object
#  11  q6           149 non-null    object
#  12  q7           149 non-null    object
#  13  q8           149 non-null    object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 16.5+ KB

# %%
df['q1']. value_counts()
# Out:
# Strongly Agree       53
# Agree                49
# Neutral              20
# Disagree             18
# Strongly Disagree     9
# Name: q1, dtype: int64

# %%
df['q4'].value_counts().plot(kind = "bar",color = "#61d129")
# Out:
# <AxesSubplot:>

# %%
df_transformed = df.replace(['Strongly Agree',
                   'Agree', 
                   'Neutral', 
                   'Disagree', 
                   'Strongly Disagree'], [5,4,3,2,1])
df_transformed.tail(5)
# Out:
#       id   age  height country  language  freq_travel   q1  q2   q3   q4  q5  \
# 145  172  21.0     175      RU       1.0          4.0  3.0   3  4.0  5.0   4
# 146  173  40.0     163      CN       1.0          1.0  5.0   5  5.0  5.0   5
# 147  174   NaN     182      AR       2.0          3.0  4.0   4  4.0  5.0   4
# 148  176  35.0     160      PH       1.0          3.0  5.0   4  5.0  5.0   3
# 149  177   NaN     160      CN       5.0          2.0  1.0   5  3.0  5.0   5
#
#       q6   q7   q8
# 145  5.0  4.0  4.0
# 146  5.0  5.0  5.0
# 147  4.0  4.0  5.0
# 148  4.0  4.0  5.0
# 149  5.0  5.0  5.0

# %%
df_transformed.dtypes
# Out:
# id               int64
# age            float64
# height           int64
# country         object
# language       float64
# freq_travel    float64
# q1             float64
# q2               int64
# q3             float64
# q4             float64
# q5               int64
# q6             float64
# q7             float64
# q8             float64
# dtype: object

# %%
df_transformed.columns
# Out:
# Index(['id', 'age', 'height', 'country', 'language', 'freq_travel', 'q1', 'q2',
#        'q3', 'q4', 'q5', 'q6', 'q7', 'q8'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

names = df_transformed.columns
plt.figure(figsize = (25,11))
sns.heatmap(df_transformed.isna().values,  xticklabels=df_transformed.columns)
#plt.title("Missing values in the dataset", size=20)
# Out:
# <AxesSubplot:>

# %%
df_transformed = df_transformed.drop(['id','age','height','country','language','freq_travel'], axis=1)
df_transformed
# Out:
#       q1  q2   q3   q4  q5   q6   q7   q8
# 0    4.0   4  4.0  4.0   3  2.0  3.0  3.0
# 1    5.0   4  3.0  4.0   5  5.0  4.0  4.0
# 2    4.0   4  5.0  4.0   5  4.0  5.0  4.0
# 3    4.0   4  4.0  4.0   5  4.0  4.0  3.0
# 4    5.0   4  5.0  3.0   3  4.0  4.0  5.0
# ..   ...  ..  ...  ...  ..  ...  ...  ...
# 145  3.0   3  4.0  5.0   4  5.0  4.0  4.0
# 146  5.0   5  5.0  5.0   5  5.0  5.0  5.0
# 147  4.0   4  4.0  5.0   4  4.0  4.0  5.0
# 148  5.0   4  5.0  5.0   3  4.0  4.0  5.0
# 149  1.0   5  3.0  5.0   5  5.0  5.0  5.0
#
# [150 rows x 8 columns]

# %%
df_transformed.isnull()
# Out:
#         q1     q2     q3     q4     q5     q6     q7     q8
# 0    False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...
# 145  False  False  False  False  False  False  False  False
# 146  False  False  False  False  False  False  False  False
# 147  False  False  False  False  False  False  False  False
# 148  False  False  False  False  False  False  False  False
# 149  False  False  False  False  False  False  False  False
#
# [150 rows x 8 columns]

# %%
df_transformed.isnull().any(axis=1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
df_transformed[+(df_transformed.isnull().any(axis=1))]
# Out:
#       q1  q2   q3   q4  q5   q6   q7   q8
# 8    NaN   4  3.0  3.0   5  5.0  5.0  3.0
# 62   5.0   5  5.0  4.0   5  NaN  5.0  5.0
# 65   3.0   3  3.0  NaN   4  5.0  4.0  5.0
# 71   4.0   4  NaN  4.0   5  2.0  4.0  4.0
# 89   4.0   3  4.0  4.0   5  3.0  3.0  NaN
# 106  1.0   2  5.0  5.0   5  5.0  NaN  5.0

# %%
column_means = df_transformed.mean()
column_means
# Out:
# q1    3.798658
# q2    4.046667
# q3    4.073826
# q4    4.476510
# q5    4.313333
# q6    4.268456
# q7    4.060403
# q8    4.120805
# dtype: float64

# %%
df_transformed_without_NaN = df_transformed.fillna(column_means)
df_transformed_without_NaN
# Out:
#       q1  q2   q3   q4  q5   q6   q7   q8
# 0    4.0   4  4.0  4.0   3  2.0  3.0  3.0
# 1    5.0   4  3.0  4.0   5  5.0  4.0  4.0
# 2    4.0   4  5.0  4.0   5  4.0  5.0  4.0
# 3    4.0   4  4.0  4.0   5  4.0  4.0  3.0
# 4    5.0   4  5.0  3.0   3  4.0  4.0  5.0
# ..   ...  ..  ...  ...  ..  ...  ...  ...
# 145  3.0   3  4.0  5.0   4  5.0  4.0  4.0
# 146  5.0   5  5.0  5.0   5  5.0  5.0  5.0
# 147  4.0   4  4.0  5.0   4  4.0  4.0  5.0
# 148  5.0   4  5.0  5.0   3  4.0  4.0  5.0
# 149  1.0   5  3.0  5.0   5  5.0  5.0  5.0
#
# [150 rows x 8 columns]

# %%
df_transformed_without_NaN[df_transformed_without_NaN.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [q1, q2, q3, q4, q5, q6, q7, q8]
# Index: []

# %%
df_transformed.dropna(inplace=True)

# %%
len(df_transformed)
# Out:
# 144
